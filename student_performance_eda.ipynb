# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
df = pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.isna().sum()
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# gender                          2
# race/ethnicity                  5
# parental level of education     6
# lunch                           2
# test preparation course         2
# math score                     81
# reading score                  72
# writing score                  77
# dtype: int64

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
numerical_features = [feature for feature in df.columns if df[feature].dtype!="O"]
categorical_features = [feature for feature in df.columns if df[feature].dtype=="O"]

# %%
numerical_features
# Out:
# ['math score', 'reading score', 'writing score']

# %%
categorical_features
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course']

# %%
df["total_score"] = (df["math score"]+df["reading score"]+df["writing score"])

# %%
df["avg_score"] = df["total_score"]/3

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  avg_score
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %%
## Exploring more visualization

fig, axis = plt.subplots(1,2,figsize=(10,6))
plt.subplot(121)
sns.histplot(data=df, x="avg_score", bins=30, kde=True, color="g")
plt.subplot(122)
sns.histplot(data=df, x="avg_score", bins=30, hue="gender", kde=True)
# Out:
# <Axes: xlabel='avg_score', ylabel='Count'>

# %% [markdown]
# ## insights
# - standard lunch helps student perform better
# - standard lunch helps student well in exam whether male or female

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df, x="avg_score",hue="lunch", kde=True)
plt.subplot(142)
sns.histplot(data=df[df.gender=="female"], x="avg_score",hue="lunch", kde=True)
plt.subplot(143)
sns.histplot(data=df[df.gender=="male"], x="avg_score",hue="lunch", kde=True)
# Out:
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\156923915.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\156923915.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\156923915.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# <Axes: xlabel='avg_score', ylabel='Count'>

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  avg_score
# 0          218  72.666667
# 1          247  82.333333
# 2          278  92.666667
# 3          148  49.333333
# ...

# %% [markdown]
# ## insights
# - in general parental education dont help student perform well in exams
# - 2nd plot we can see no effect of parents education on female child
# - 3rd plot shows that parent whose education is of associate degree od masters degree their child tend to perform better

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df, x="avg_score",hue="parental level of education", kde=True)
plt.subplot(142)
sns.histplot(data=df[df.gender=="female"], x="avg_score",hue="parental level of education", kde=True)
plt.subplot(143)
sns.histplot(data=df[df.gender=="male"], x="avg_score",hue="parental level of education", kde=True)
# Out:
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\1582052790.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\1582052790.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\1582052790.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# <Axes: xlabel='avg_score', ylabel='Count'>

# %% [markdown]
# ## insights
# - student of group a or group b tends to perform poorly in exams
# - student of group a and group b tends to perform poorly in exams irrespective of whether they are male or female

# %%
plt.subplots(1,3,figsize=(25,6))
plt.subplot(141)
sns.histplot(data=df, x="avg_score",hue="race/ethnicity", kde=True)
plt.subplot(142)
sns.histplot(data=df[df.gender=="female"], x="avg_score",hue="race/ethnicity", kde=True)
plt.subplot(143)
sns.histplot(data=df[df.gender=="male"], x="avg_score",hue="race/ethnicity", kde=True)
# Out:
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\767213573.py:2: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(141)
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\767213573.py:4: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(142)
# C:\Users\Sunny\AppData\Local\Temp\ipykernel_18780\767213573.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   plt.subplot(143)
# <Axes: xlabel='avg_score', ylabel='Count'>
